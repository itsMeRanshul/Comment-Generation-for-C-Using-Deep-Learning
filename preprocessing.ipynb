# %%
# ===============================
# Project: Context-Aware Comment Generator for C Code
# Phase 1 + 2: Dataset Preparation + AST Linearization
# Dataset Location: C:\PBL-Compiler\DATASET (FormAI Dataset)
# ===============================

import os
import json
import re
import pycparser
from pycparser import parse_file, c_ast

# %%
# ===== CONFIGURATION =====
DATASET_DIR = 'C:/Users/Downloads/FormAI_dataset_C_samples-V1/DATASET'
OUTPUT_FILE = "structured_dataset_with_ast.json"

# ===== PREPROCESSING SKIP CHECK =====
if os.path.exists(OUTPUT_FILE):
    print(f"✅ File '{OUTPUT_FILE}' already exists. Skipping preprocessing.")
    exit()

# Get path to pycparser's fake libc includes
FAKE_LIBC_DIR = os.path.join(os.path.dirname(pycparser.__file__), 'utils', 'fake_libc_include')

processed_data = []
skipped_files = []
print_limit = 5
print_count = 0

# === UTILITY FUNCTIONS ===

def remove_metadata(code):
    lines = code.strip().splitlines()
    if lines and lines[0].startswith("//FormAI"):
        return "\n".join(lines[1:])
    return code

# ✅ NEW: Extract real comments and strip them from code
def extract_comments_and_strip(code):
    single_line_comments = re.findall(r'//.*', code)
    multi_line_comments = re.findall(r'/\*[\s\S]*?\*/', code)
    all_comments = single_line_comments + multi_line_comments
    code_wo_comments = re.sub(r'//.*|/\*[\s\S]*?\*/', '', code)
    return all_comments, code_wo_comments

def clean_code_for_parser(code):
    lines = code.splitlines()
    lines = [line for line in lines if not line.strip().startswith("#")]
    return "\n".join(lines)

def linearize_ast(ast):
    result = []
    def visit(node):
        if isinstance(node, c_ast.Node):
            result.append(node.__class__.__name__)
            for _, child in node.children():
                visit(child)
    visit(ast)
    return " ".join(result)

# === MAIN LOOP ===

print("🔍 Processing files...")

for file in os.listdir(DATASET_DIR):
    if file.endswith(".c"):
        print(f"Processing {file} ...")
        filepath = os.path.join(DATASET_DIR, file)
        with open(filepath, "r", encoding="utf-8", errors="ignore") as f:
            raw_code = f.read()

        # Step 1: Remove FormAI metadata
        code_clean_meta = remove_metadata(raw_code)

        # ✅ Step 2: Extract and strip real comments
        extracted_comments, code_clean = extract_comments_and_strip(code_clean_meta)

        # ✅ Skip files with no comments
        if not extracted_comments:
            skipped_files.append((file, "No comments found in file"))
            continue

        # Step 3: Clean preprocessor lines for parsing
        code_for_ast = clean_code_for_parser(code_clean)

        # Step 4: Write cleaned code to temp file for pycparser
        tmp_file = 'temp.c'
        with open(tmp_file, 'w', encoding='utf-8') as tf:
            tf.write(code_for_ast)

        # Step 5: Parse with pycparser
        try:
            ast = parse_file(tmp_file, use_cpp=True, cpp_args=[r'-I' + FAKE_LIBC_DIR])
        except Exception as e:
            skipped_files.append((file, f"AST parsing failed: {e}"))
            continue

        # Step 6: Linearize AST
        ast_linear = linearize_ast(ast)

        # Step 7: Combine AST and code for input
        combined_input = code_clean + " <AST> " + ast_linear

        # ✅ Step 8: Use real comment(s)
        comment = " ".join(extracted_comments).strip()

        # Optional: Debug info
        if print_count < print_limit:
            print(f"\nFile: {file}")
            try:
                ast.show()
            except:
                print("[!] AST tree display error")
            print("Linearized AST:", ast_linear)
            print("Combined Input:", combined_input)
            print("Extracted Comment:", comment)
            print("=" * 50)
            print_count += 1

        # Step 9: Append processed data
        processed_data.append({
            "file": file,
            "code": code_clean.strip(),
            "comment": comment,
            "ast_linear": ast_linear,
            "combined_input": combined_input
        })

# Remove temporary file
if os.path.exists(tmp_file):
    os.remove(tmp_file)

# Save processed dataset
with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
    json.dump(processed_data, f, indent=2)

print(f"✅ Saved {len(processed_data)} valid C programs to '{OUTPUT_FILE}'")
print(f"🚫 Skipped {len(skipped_files)} files due to errors.")

if skipped_files:
    with open("skipped_files_log.txt", "w") as logf:
        for fname, reason in skipped_files:
            logf.write(f"{fname}: {reason}\n")
    print("📄 Skipped file log saved to 'skipped_files_log.txt'")
# Out:
# 🔍 Processing files...
# Processing FormAI_1.c ...
#
# File: FormAI_1.c
# FileAST:
#   FuncDef:
#     Decl: main, [], [], [], []
#       FuncDecl:
#         TypeDecl: main, [], None
#           IdentifierType: ['int']
#     Compound:
#       Decl: n, [], [], [], []
#         TypeDecl: n, [], None
#           IdentifierType: ['int']
#         Constant: int, 7
#       Decl: arr, [], [], [], []
#         ArrayDecl: []
#           ArrayDecl: []
#             TypeDecl: arr, [], None
#               IdentifierType: ['int']
#             ID: n
#           ID: n
#       For:
#         DeclList:
#           Decl: i, [], [], [], []
#             TypeDecl: i, [], None
#               IdentifierType: ['int']
#             Constant: int, 0
#         BinaryOp: <
#           ID: i
#           ID: n
#         UnaryOp: p++
#           ID: i
#         Compound:
#           For:
#             DeclList:
#               Decl: j, [], [], [], []
#                 TypeDecl: j, [], None
#                   IdentifierType: ['int']
#                 Constant: int, 0
#             BinaryOp: <
#               ID: j
#               ID: n
#             UnaryOp: p++
#               ID: j
#             Compound:
#               If:
#                 BinaryOp: ==
#                   ID: i
#                   Constant: int, 0
#                 Compound:
#                   Assignment: =
#                     ArrayRef:
#                       ArrayRef:
#                         ID: arr
#                         ID: i
#                       ID: j
#                     BinaryOp: +
#                       ID: j
#                       Constant: int, 1
#                 If:
#                   BinaryOp: ==
#                     ID: j
#                     Constant: int, 0
#                   Compound:
#                     Assignment: =
#                       ArrayRef:
#                         ArrayRef:
#                           ID: arr
#                           ID: i
#                         ID: j
#                       BinaryOp: +
#                         ID: i
#                         Constant: int, 1
#                   Compound:
#                     Assignment: =
#                       ArrayRef:
#                         ArrayRef:
#                           ID: arr
#                           ID: i
#                         ID: j
#                       BinaryOp: +
#                         ArrayRef:
#                           ArrayRef:
#                             ID: arr
#                             BinaryOp: -
#                               ID: i
#                               Constant: int, 1
#                           ID: j
#                         ArrayRef:
#                           ArrayRef:
#                             ID: arr
#                             ID: i
#                           BinaryOp: -
#                             ID: j
#                             Constant: int, 1
#       FuncCall:
#         ID: printf
#         ExprList:
#           Constant: string, "The Pascal's Triangle of order %d is:\n"
#           ID: n
#       For:
#         DeclList:
#           Decl: i, [], [], [], []
#             TypeDecl: i, [], None
#               IdentifierType: ['int']
#             Constant: int, 0
#         BinaryOp: <
#           ID: i
#           ID: n
#         UnaryOp: p++
#           ID: i
#         Compound:
#           For:
#             DeclList:
#               Decl: j, [], [], [], []
#                 TypeDecl: j, [], None
#                   IdentifierType: ['int']
#                 Constant: int, 0
#             BinaryOp: <
#               ID: j
#               ID: n
#             UnaryOp: p++
#               ID: j
#             Compound:
#               FuncCall:
#                 ID: printf
#                 ExprList:
#                   Constant: string, "%d\t"
#                   ArrayRef:
#                     ArrayRef:
#                       ID: arr
#                       ID: i
#                     ID: j
#           FuncCall:
#             ID: printf
#             ExprList:
#               Constant: string, "\n"
#       Return:
#         Constant: int, 0
# Linearized AST: FileAST FuncDef Decl FuncDecl TypeDecl IdentifierType Compound Decl TypeDecl IdentifierType Constant Decl ArrayDecl ArrayDecl TypeDecl IdentifierType ID ID For DeclList Decl TypeDecl IdentifierType Constant BinaryOp ID ID UnaryOp ID Compound For DeclList Decl TypeDecl IdentifierType Constant BinaryOp ID ID UnaryOp ID Compound If BinaryOp ID Constant Compound Assignment ArrayRef ArrayRef ID ID ID BinaryOp ID Constant If BinaryOp ID Constant Compound Assignment ArrayRef ArrayRef ID ID ID BinaryOp ID Constant Compound Assignment ArrayRef ArrayRef ID ID ID BinaryOp ArrayRef ArrayRef ID BinaryOp ID Constant ID ArrayRef ArrayRef ID ID BinaryOp ID Constant FuncCall ID ExprList Constant ID For DeclList Decl TypeDecl IdentifierType Constant BinaryOp ID ID UnaryOp ID Compound For DeclList Decl TypeDecl IdentifierType Constant BinaryOp ID ID UnaryOp ID Compound FuncCall ID ExprList Constant ArrayRef ArrayRef ID ID ID FuncCall ID ExprList Constant Return Constant
# Combined Input: #include <stdio.h>
#
# int main() {
#   int n = 7;
#   int arr[n][n];
#
#
#   for(int i = 0; i < n; i++) {
#     for(int j = 0; j < n; j++) {
#       if(i == 0) {
#         arr[i][j] = j + 1;
#       } else if(j == 0) {
#         arr[i][j] = i + 1;
#       } else {
#         arr[i][j] = arr[i-1][j] + arr[i][j-1];
#       }
#     }
#   }
#
#
#   printf("The Pascal's Triangle of order %d is:\n", n);
#   for(int i = 0; i < n; i++) {
#     for(int j = 0; j < n; j++) {
#       printf("%d\t", arr[i][j]);
#     }
#     printf("\n");
#   }
#
#   return 0;
# } <AST> FileAST FuncDef Decl FuncDecl TypeDecl IdentifierType Compound Decl TypeDecl IdentifierType Constant Decl ArrayDecl ArrayDecl TypeDecl IdentifierType ID ID For DeclList Decl TypeDecl IdentifierType Constant BinaryOp ID ID UnaryOp ID Compound For DeclList Decl TypeDecl IdentifierType Constant BinaryOp ID ID UnaryOp ID Compound If BinaryOp ID Constant Compound Assignment ArrayRef ArrayRef ID ID ID BinaryOp ID Constant If BinaryOp ID Constant Compound Assignment ArrayRef ArrayRef ID ID ID BinaryOp ID Constant Compound Assignment ArrayRef ArrayRef ID ID ID BinaryOp ArrayRef ArrayRef ID BinaryOp ID Constant ID ArrayRef ArrayRef ID ID BinaryOp ID Constant FuncCall ID ExprList Constant ID For DeclList Decl TypeDecl IdentifierType Constant BinaryOp ID ID UnaryOp ID Compound For DeclList Decl TypeDecl IdentifierType Constant BinaryOp ID ID UnaryOp ID Compound FuncCall ID ExprList Constant ArrayRef ArrayRef ID ID ID FuncCall ID ExprList Constant Return Constant
# Extracted Comment: // filling the matrix // printing the matrix
# ==================================================
# Processing FormAI_10.c ...
# Processing FormAI_100.c ...
#
# File: FormAI_100.c
# FileAST:
#   FuncDef:
#     Decl: main, [], [], [], []
#       FuncDecl:
#         TypeDecl: main, [], None
#           IdentifierType: ['int']
#     Compound:
#       Decl: n, [], [], [], []
#         TypeDecl: n, [], None
#           IdentifierType: ['int']
#       Decl: i, [], [], [], []
#         TypeDecl: i, [], None
#           IdentifierType: ['int']
#       FuncCall:
#         ID: printf
#         ExprList:
#           Constant: string, "Enter the number of terms you want to generate in the Fibonacci Sequence: "
#       FuncCall:
#         ID: scanf
#         ExprList:
#           Constant: string, "%d"
#           UnaryOp: &
#             ID: n
#       Decl: fib, [], [], [], []
#         ArrayDecl: []
#           TypeDecl: fib, [], None
#             IdentifierType: ['int']
#           ID: n
#       Assignment: =
#         ArrayRef:
#           ID: fib
#           Constant: int, 0
#         Constant: int, 0
#       Assignment: =
#         ArrayRef:
#           ID: fib
#           Constant: int, 1
#         Constant: int, 1
#       For:
#         Assignment: =
#           ID: i
#           Constant: int, 2
#         BinaryOp: <
#           ID: i
#           ID: n
#         UnaryOp: p++
#           ID: i
#         Compound:
#           Assignment: =
#             ArrayRef:
#               ID: fib
#               ID: i
#             BinaryOp: +
#               ArrayRef:
#                 ID: fib
#                 BinaryOp: -
#                   ID: i
#                   Constant: int, 1
#               ArrayRef:
#                 ID: fib
#                 BinaryOp: -
#                   ID: i
#                   Constant: int, 2
#       FuncCall:
#         ID: printf
#         ExprList:
#           Constant: string, "\nFibonacci Sequence for %d terms is: "
#           ID: n
#       For:
#         Assignment: =
#           ID: i
#           Constant: int, 0
#         BinaryOp: <
#           ID: i
#           ID: n
#         UnaryOp: p++
#           ID: i
#         Compound:
#           FuncCall:
#             ID: printf
#             ExprList:
#               Constant: string, "%d "
#               ArrayRef:
#                 ID: fib
#                 ID: i
#       FuncCall:
#         ID: printf
#         ExprList:
#           Constant: string, "\n\nVisualizing the Fibonacci Sequence:\n"
#       For:
#         Assignment: =
#           ID: i
#           Constant: int, 0
#         BinaryOp: <
#           ID: i
#           ID: n
#         UnaryOp: p++
#           ID: i
#         Compound:
#           Decl: j, [], [], [], []
#             TypeDecl: j, [], None
#               IdentifierType: ['int']
#           For:
#             Assignment: =
#               ID: j
#               Constant: int, 0
#             BinaryOp: <
#               ID: j
#               ArrayRef:
#                 ID: fib
#                 ID: i
#             UnaryOp: p++
#               ID: j
#             Compound:
#               FuncCall:
#                 ID: printf
#                 ExprList:
#                   Constant: string, "* "
#           FuncCall:
#             ID: printf
#             ExprList:
#               Constant: string, "\n"
#       FuncCall:
#         ID: printf
#         ExprList:
#           Constant: string, "\n"
#       Return:
#         Constant: int, 0
# Linearized AST: FileAST FuncDef Decl FuncDecl TypeDecl IdentifierType Compound Decl TypeDecl IdentifierType Decl TypeDecl IdentifierType FuncCall ID ExprList Constant FuncCall ID ExprList Constant UnaryOp ID Decl ArrayDecl TypeDecl IdentifierType ID Assignment ArrayRef ID Constant Constant Assignment ArrayRef ID Constant Constant For Assignment ID Constant BinaryOp ID ID UnaryOp ID Compound Assignment ArrayRef ID ID BinaryOp ArrayRef ID BinaryOp ID Constant ArrayRef ID BinaryOp ID Constant FuncCall ID ExprList Constant ID For Assignment ID Constant BinaryOp ID ID UnaryOp ID Compound FuncCall ID ExprList Constant ArrayRef ID ID FuncCall ID ExprList Constant For Assignment ID Constant BinaryOp ID ID UnaryOp ID Compound Decl TypeDecl IdentifierType For Assignment ID Constant BinaryOp ID ArrayRef ID ID UnaryOp ID Compound FuncCall ID ExprList Constant FuncCall ID ExprList Constant FuncCall ID ExprList Constant Return Constant
# Combined Input: #include <stdio.h>
# #include <stdlib.h>
#
# int main() {
#     int n, i;
#
#     printf("Enter the number of terms you want to generate in the Fibonacci Sequence: ");
#     scanf("%d", &n);
#
#     int fib[n];
#     fib[0] = 0;
#     fib[1] = 1;
#
#
#     for (i = 2; i < n; i++) {
#         fib[i] = fib[i-1] + fib[i-2];
#     }
#
#     printf("\nFibonacci Sequence for %d terms is: ", n);
#
#
#     for (i = 0; i < n; i++) {
#         printf("%d ", fib[i]);
#     }
#
#
#     printf("\n\nVisualizing the Fibonacci Sequence:\n");
#
#     for (i = 0; i < n; i++) {
#         int j;
#         for (j = 0; j < fib[i]; j++) {
#             printf("* ");
#         }
#         printf("\n");
#     }
#
#     printf("\n");
#     return 0;
# } <AST> FileAST FuncDef Decl FuncDecl TypeDecl IdentifierType Compound Decl TypeDecl IdentifierType Decl TypeDecl IdentifierType FuncCall ID ExprList Constant FuncCall ID ExprList Constant UnaryOp ID Decl ArrayDecl TypeDecl IdentifierType ID Assignment ArrayRef ID Constant Constant Assignment ArrayRef ID Constant Constant For Assignment ID Constant BinaryOp ID ID UnaryOp ID Compound Assignment ArrayRef ID ID BinaryOp ArrayRef ID BinaryOp ID Constant ArrayRef ID BinaryOp ID Constant FuncCall ID ExprList Constant ID For Assignment ID Constant BinaryOp ID ID UnaryOp ID Compound FuncCall ID ExprList Constant ArrayRef ID ID FuncCall ID ExprList Constant For Assignment ID Constant BinaryOp ID ID UnaryOp ID Compound Decl TypeDecl IdentifierType For Assignment ID Constant BinaryOp ID ArrayRef ID ID UnaryOp ID Compound FuncCall ID ExprList Constant FuncCall ID ExprList Constant FuncCall ID ExprList Constant Return Constant
# Extracted Comment: // starting with index 2, generates the remaining terms in the sequence // prints the sequence // visualizes the sequence using stars, with each star representing one term in the sequence
# ==================================================
# Processing FormAI_1000.c ...
# Processing FormAI_10000.c ...
# Processing FormAI_100000.c ...
# Processing FormAI_100001.c ...
#
# File: FormAI_100001.c
# FileAST:
#   Decl: board, [], [], [], []
#     ArrayDecl: []
#       ArrayDecl: []
#         TypeDecl: board, [], None
#           IdentifierType: ['int']
#         ID: SIZE
#       ID: SIZE
#   FuncDef:
#     Decl: print_board, [], [], [], []
#       FuncDecl:
#         TypeDecl: print_board, [], None
#           IdentifierType: ['void']
#     Compound:
#       Decl: row, [], [], [], []
#         TypeDecl: row, [], None
#           IdentifierType: ['int']
#       Decl: col, [], [], [], []
#         TypeDecl: col, [], None
#           IdentifierType: ['int']
#       For:
#         Assignment: =
#           ID: row
#           Constant: int, 0
#         BinaryOp: <
#           ID: row
#           ID: SIZE
#         UnaryOp: p++
#           ID: row
#         Compound:
#           For:
#             Assignment: =
#               ID: col
#               Constant: int, 0
#             BinaryOp: <
#               ID: col
#               ID: SIZE
#             UnaryOp: p++
#               ID: col
#             Compound:
#               FuncCall:
#                 ID: printf
#                 ExprList:
#                   Constant: string, "%d "
#                   ArrayRef:
#                     ArrayRef:
#                       ID: board
#                       ID: row
#                     ID: col
#           FuncCall:
#             ID: printf
#             ExprList:
#               Constant: string, "\n"
#   FuncDef:
#     Decl: solve, [], [], [], []
#       FuncDecl:
#         TypeDecl: solve, [], None
#           IdentifierType: ['void']
#     Compound:
#       Decl: row, [], [], [], []
#         TypeDecl: row, [], None
#           IdentifierType: ['int']
#       Decl: col, [], [], [], []
#         TypeDecl: col, [], None
#           IdentifierType: ['int']
#       Decl: num, [], [], [], []
#         TypeDecl: num, [], None
#           IdentifierType: ['int']
#       For:
#         Assignment: =
#           ID: row
#           Constant: int, 0
#         BinaryOp: <
#           ID: row
#           ID: SIZE
#         UnaryOp: p++
#           ID: row
#         Compound:
#           For:
#             Assignment: =
#               ID: col
#               Constant: int, 0
#             BinaryOp: <
#               ID: col
#               ID: SIZE
#             UnaryOp: p++
#               ID: col
#             Compound:
#               If:
#                 BinaryOp: ==
#                   ArrayRef:
#                     ArrayRef:
#                       ID: board
#                       ID: row
#                     ID: col
#                   Constant: int, 0
#                 Compound:
#                   For:
#                     Assignment: =
#                       ID: num
#                       Constant: int, 1
#                     BinaryOp: <=
#                       ID: num
#                       ID: SIZE
#                     UnaryOp: p++
#                       ID: num
#                     Compound:
#                       Decl: i, [], [], [], []
#                         TypeDecl: i, [], None
#                           IdentifierType: ['int']
#                       Decl: j, [], [], [], []
#                         TypeDecl: j, [], None
#                           IdentifierType: ['int']
#                       Decl: valid, [], [], [], []
#                         TypeDecl: valid, [], None
#                           IdentifierType: ['int']
#                         Constant: int, 1
#                       For:
#                         Assignment: =
#                           ID: i
#                           Constant: int, 0
#                         BinaryOp: <
#                           ID: i
#                           ID: SIZE
#                         UnaryOp: p++
#                           ID: i
#                         Compound:
#                           If:
#                             BinaryOp: ==
#                               ArrayRef:
#                                 ArrayRef:
#                                   ID: board
#                                   ID: i
#                                 ID: col
#                               ID: num
#                             Compound:
#                               Assignment: =
#                                 ID: valid
#                                 Constant: int, 0
#                               Break:
#                       For:
#                         Assignment: =
#                           ID: j
#                           Constant: int, 0
#                         BinaryOp: <
#                           ID: j
#                           ID: SIZE
#                         UnaryOp: p++
#                           ID: j
#                         Compound:
#                           If:
#                             BinaryOp: ==
#                               ArrayRef:
#                                 ArrayRef:
#                                   ID: board
#                                   ID: row
#                                 ID: j
#                               ID: num
#                             Compound:
#                               Assignment: =
#                                 ID: valid
#                                 Constant: int, 0
#                               Break:
#                       Decl: box_row, [], [], [], []
#                         TypeDecl: box_row, [], None
#                           IdentifierType: ['int']
#                         BinaryOp: /
#                           ID: row
#                           Constant: int, 3
#                       Decl: box_col, [], [], [], []
#                         TypeDecl: box_col, [], None
#                           IdentifierType: ['int']
#                         BinaryOp: /
#                           ID: col
#                           Constant: int, 3
#                       For:
#                         Assignment: =
#                           ID: i
#                           BinaryOp: *
#                             ID: box_row
#                             Constant: int, 3
#                         BinaryOp: <
#                           ID: i
#                           BinaryOp: +
#                             BinaryOp: *
#                               ID: box_row
#                               Constant: int, 3
#                             Constant: int, 3
#                         UnaryOp: p++
#                           ID: i
#                         Compound:
#                           For:
#                             Assignment: =
#                               ID: j
#                               BinaryOp: *
#                                 ID: box_col
#                                 Constant: int, 3
#                             BinaryOp: <
#                               ID: j
#                               BinaryOp: +
#                                 BinaryOp: *
#                                   ID: box_col
#                                   Constant: int, 3
#                                 Constant: int, 3
#                             UnaryOp: p++
#                               ID: j
#                             Compound:
#                               If:
#                                 BinaryOp: ==
#                                   ArrayRef:
#                                     ArrayRef:
#                                       ID: board
#                                       ID: i
#                                     ID: j
#                                   ID: num
#                                 Compound:
#                                   Assignment: =
#                                     ID: valid
#                                     Constant: int, 0
#                                   Break:
#                       If:
#                         ID: valid
#                         Compound:
#                           Assignment: =
#                             ArrayRef:
#                               ArrayRef:
#                                 ID: board
#                                 ID: row
#                               ID: col
#                             ID: num
#                           FuncCall:
#                             ID: solve
#                           Assignment: =
#                             ArrayRef:
#                               ArrayRef:
#                                 ID: board
#                                 ID: row
#                               ID: col
#                             Constant: int, 0
#                   Return:
#       FuncCall:
#         ID: print_board
#       FuncCall:
#         ID: exit
#         ExprList:
#           Constant: int, 0
#   FuncDef:
#     Decl: main, [], [], [], []
#       FuncDecl:
#         TypeDecl: main, [], None
#           IdentifierType: ['int']
#     Compound:
#       Decl: row, [], [], [], []
#         TypeDecl: row, [], None
#           IdentifierType: ['int']
#       Decl: col, [], [], [], []
#         TypeDecl: col, [], None
#           IdentifierType: ['int']
#       For:
#         Assignment: =
#           ID: row
#           Constant: int, 0
#         BinaryOp: <
#           ID: row
#           ID: SIZE
#         UnaryOp: p++
#           ID: row
#         Compound:
#           For:
#             Assignment: =
#               ID: col
#               Constant: int, 0
#             BinaryOp: <
#               ID: col
#               ID: SIZE
#             UnaryOp: p++
#               ID: col
#             Compound:
#               FuncCall:
#                 ID: scanf
#                 ExprList:
#                   Constant: string, "%d"
#                   UnaryOp: &
#                     ArrayRef:
#                       ArrayRef:
#                         ID: board
#                         ID: row
#                       ID: col
#       FuncCall:
#         ID: solve
#       FuncCall:
#         ID: printf
#         ExprList:
#           Constant: string, "No solution found."
#       Return:
#         Constant: int, 0
# Linearized AST: FileAST Decl ArrayDecl ArrayDecl TypeDecl IdentifierType ID ID FuncDef Decl FuncDecl TypeDecl IdentifierType Compound Decl TypeDecl IdentifierType Decl TypeDecl IdentifierType For Assignment ID Constant BinaryOp ID ID UnaryOp ID Compound For Assignment ID Constant BinaryOp ID ID UnaryOp ID Compound FuncCall ID ExprList Constant ArrayRef ArrayRef ID ID ID FuncCall ID ExprList Constant FuncDef Decl FuncDecl TypeDecl IdentifierType Compound Decl TypeDecl IdentifierType Decl TypeDecl IdentifierType Decl TypeDecl IdentifierType For Assignment ID Constant BinaryOp ID ID UnaryOp ID Compound For Assignment ID Constant BinaryOp ID ID UnaryOp ID Compound If BinaryOp ArrayRef ArrayRef ID ID ID Constant Compound For Assignment ID Constant BinaryOp ID ID UnaryOp ID Compound Decl TypeDecl IdentifierType Decl TypeDecl IdentifierType Decl TypeDecl IdentifierType Constant For Assignment ID Constant BinaryOp ID ID UnaryOp ID Compound If BinaryOp ArrayRef ArrayRef ID ID ID ID Compound Assignment ID Constant Break For Assignment ID Constant BinaryOp ID ID UnaryOp ID Compound If BinaryOp ArrayRef ArrayRef ID ID ID ID Compound Assignment ID Constant Break Decl TypeDecl IdentifierType BinaryOp ID Constant Decl TypeDecl IdentifierType BinaryOp ID Constant For Assignment ID BinaryOp ID Constant BinaryOp ID BinaryOp BinaryOp ID Constant Constant UnaryOp ID Compound For Assignment ID BinaryOp ID Constant BinaryOp ID BinaryOp BinaryOp ID Constant Constant UnaryOp ID Compound If BinaryOp ArrayRef ArrayRef ID ID ID ID Compound Assignment ID Constant Break If ID Compound Assignment ArrayRef ArrayRef ID ID ID ID FuncCall ID Assignment ArrayRef ArrayRef ID ID ID Constant Return FuncCall ID FuncCall ID ExprList Constant FuncDef Decl FuncDecl TypeDecl IdentifierType Compound Decl TypeDecl IdentifierType Decl TypeDecl IdentifierType For Assignment ID Constant BinaryOp ID ID UnaryOp ID Compound For Assignment ID Constant BinaryOp ID ID UnaryOp ID Compound FuncCall ID ExprList Constant UnaryOp ArrayRef ArrayRef ID ID ID FuncCall ID FuncCall ID ExprList Constant Return Constant
# Combined Input: #include <stdio.h>
# #include <stdlib.h>
#
# #define SIZE 9
#
# int board[SIZE][SIZE];
#
# void print_board()
# {
#     int row, col;
#     for (row = 0; row < SIZE; row++) {
#         for (col = 0; col < SIZE; col++) {
#             printf("%d ", board[row][col]);
#         }
#         printf("\n");
#     }
# }
#
# void solve()
# {
#     int row, col, num;
#     for (row = 0; row < SIZE; row++) {
#         for (col = 0; col < SIZE; col++) {
#             if (board[row][col] == 0) {
#                 for (num = 1; num <= SIZE; num++) {
#                     int i, j;
#                     int valid = 1;
#                     for (i = 0; i < SIZE; i++) {
#                         if (board[i][col] == num) {
#                             valid = 0;
#                             break;
#                         }
#                     }
#                     for (j = 0; j < SIZE; j++) {
#                         if (board[row][j] == num) {
#                             valid = 0;
#                             break;
#                         }
#                     }
#                     int box_row = row / 3;
#                     int box_col = col / 3;
#                     for (i = box_row*3; i < box_row*3+3; i++) {
#                         for (j = box_col*3; j < box_col*3+3; j++) {
#                             if (board[i][j] == num) {
#                                 valid = 0;
#                                 break;
#                             }
#                         }
#                     }
#                     if (valid) {
#                         board[row][col] = num;
#                         solve();
#                         board[row][col] = 0;
#                     }
#                 }
#                 return;
#             }
#         }
#     }
#     print_board();
#     exit(0);
# }
#
# int main()
# {
#
#     int row, col;
#     for (row = 0; row < SIZE; row++) {
#         for (col = 0; col < SIZE; col++) {
#             scanf("%d", &board[row][col]);
#         }
#     }
#
#     solve();
#     printf("No solution found.");
#     return 0;
# } <AST> FileAST Decl ArrayDecl ArrayDecl TypeDecl IdentifierType ID ID FuncDef Decl FuncDecl TypeDecl IdentifierType Compound Decl TypeDecl IdentifierType Decl TypeDecl IdentifierType For Assignment ID Constant BinaryOp ID ID UnaryOp ID Compound For Assignment ID Constant BinaryOp ID ID UnaryOp ID Compound FuncCall ID ExprList Constant ArrayRef ArrayRef ID ID ID FuncCall ID ExprList Constant FuncDef Decl FuncDecl TypeDecl IdentifierType Compound Decl TypeDecl IdentifierType Decl TypeDecl IdentifierType Decl TypeDecl IdentifierType For Assignment ID Constant BinaryOp ID ID UnaryOp ID Compound For Assignment ID Constant BinaryOp ID ID UnaryOp ID Compound If BinaryOp ArrayRef ArrayRef ID ID ID Constant Compound For Assignment ID Constant BinaryOp ID ID UnaryOp ID Compound Decl TypeDecl IdentifierType Decl TypeDecl IdentifierType Decl TypeDecl IdentifierType Constant For Assignment ID Constant BinaryOp ID ID UnaryOp ID Compound If BinaryOp ArrayRef ArrayRef ID ID ID ID Compound Assignment ID Constant Break For Assignment ID Constant BinaryOp ID ID UnaryOp ID Compound If BinaryOp ArrayRef ArrayRef ID ID ID ID Compound Assignment ID Constant Break Decl TypeDecl IdentifierType BinaryOp ID Constant Decl TypeDecl IdentifierType BinaryOp ID Constant For Assignment ID BinaryOp ID Constant BinaryOp ID BinaryOp BinaryOp ID Constant Constant UnaryOp ID Compound For Assignment ID BinaryOp ID Constant BinaryOp ID BinaryOp BinaryOp ID Constant Constant UnaryOp ID Compound If BinaryOp ArrayRef ArrayRef ID ID ID ID Compound Assignment ID Constant Break If ID Compound Assignment ArrayRef ArrayRef ID ID ID ID FuncCall ID Assignment ArrayRef ArrayRef ID ID ID Constant Return FuncCall ID FuncCall ID ExprList Constant FuncDef Decl FuncDecl TypeDecl IdentifierType Compound Decl TypeDecl IdentifierType Decl TypeDecl IdentifierType For Assignment ID Constant BinaryOp ID ID UnaryOp ID Compound For Assignment ID Constant BinaryOp ID ID UnaryOp ID Compound FuncCall ID ExprList Constant UnaryOp ArrayRef ArrayRef ID ID ID FuncCall ID FuncCall ID ExprList Constant Return Constant
# Extracted Comment: // Initialize the board // Solve the puzzle
# ==================================================
# Processing FormAI_100002.c ...
# Processing FormAI_100003.c ...
#
# File: FormAI_100003.c
# FileAST:
#   Decl: None, [], [], [], []
#     Struct: account
#       Decl: name, [], [], [], []
#         ArrayDecl: []
#           TypeDecl: name, [], None
#             IdentifierType: ['char']
#           Constant: int, 50
#       Decl: account_number, [], [], [], []
#         TypeDecl: account_number, [], None
#           IdentifierType: ['int']
#       Decl: balance, [], [], [], []
#         TypeDecl: balance, [], None
#           IdentifierType: ['float']
#   FuncDef:
#     Decl: add_account, [], [], [], []
#       FuncDecl:
#         ParamList:
#           Decl: accounts, [], [], [], []
#             PtrDecl: []
#               TypeDecl: accounts, [], None
#                 Struct: account
#           Decl: account_count, [], [], [], []
#             PtrDecl: []
#               TypeDecl: account_count, [], None
#                 IdentifierType: ['int']
#         TypeDecl: add_account, [], None
#           IdentifierType: ['void']
#     Compound:
#       Decl: name, [], [], [], []
#         ArrayDecl: []
#           TypeDecl: name, [], None
#             IdentifierType: ['char']
#           Constant: int, 50
#       Decl: balance, [], [], [], []
#         TypeDecl: balance, [], None
#           IdentifierType: ['float']
#       FuncCall:
#         ID: printf
#         ExprList:
#           Constant: string, "Enter name of account holder: "
#       FuncCall:
#         ID: scanf
#         ExprList:
#           Constant: string, "%s"
#           ID: name
#       FuncCall:
#         ID: printf
#         ExprList:
#           Constant: string, "Enter initial balance: "
#       FuncCall:
#         ID: scanf
#         ExprList:
#           Constant: string, "%f"
#           UnaryOp: &
#             ID: balance
#       Assignment: =
#         StructRef: .
#           ArrayRef:
#             ID: accounts
#             UnaryOp: *
#               ID: account_count
#           ID: account_number
#         BinaryOp: +
#           UnaryOp: *
#             ID: account_count
#           Constant: int, 1000
#       FuncCall:
#         ID: strcpy
#         ExprList:
#           StructRef: .
#             ArrayRef:
#               ID: accounts
#               UnaryOp: *
#                 ID: account_count
#             ID: name
#           ID: name
#       Assignment: =
#         StructRef: .
#           ArrayRef:
#             ID: accounts
#             UnaryOp: *
#               ID: account_count
#           ID: balance
#         ID: balance
#       FuncCall:
#         ID: printf
#         ExprList:
#           Constant: string, "New account added successfully!\n"
#       UnaryOp: p++
#         UnaryOp: *
#           ID: account_count
#   FuncDef:
#     Decl: display_accounts, [], [], [], []
#       FuncDecl:
#         ParamList:
#           Decl: accounts, [], [], [], []
#             PtrDecl: []
#               TypeDecl: accounts, [], None
#                 Struct: account
#           Decl: account_count, [], [], [], []
#             TypeDecl: account_count, [], None
#               IdentifierType: ['int']
#         TypeDecl: display_accounts, [], None
#           IdentifierType: ['void']
#     Compound:
#       FuncCall:
#         ID: printf
#         ExprList:
#           Constant: string, "Account Number\tAccount Holder\t\tBalance\n"
#       For:
#         DeclList:
#           Decl: i, [], [], [], []
#             TypeDecl: i, [], None
#               IdentifierType: ['int']
#             Constant: int, 0
#         BinaryOp: <
#           ID: i
#           ID: account_count
#         UnaryOp: p++
#           ID: i
#         Compound:
#           FuncCall:
#             ID: printf
#             ExprList:
#               Constant: string, "%d\t\t%s\t\t%.2f\n"
#               StructRef: .
#                 ArrayRef:
#                   ID: accounts
#                   ID: i
#                 ID: account_number
#               StructRef: .
#                 ArrayRef:
#                   ID: accounts
#                   ID: i
#                 ID: name
#               StructRef: .
#                 ArrayRef:
#                   ID: accounts
#                   ID: i
#                 ID: balance
#   FuncDef:
#     Decl: deposit, [], [], [], []
#       FuncDecl:
#         ParamList:
#           Decl: accounts, [], [], [], []
#             PtrDecl: []
#               TypeDecl: accounts, [], None
#                 Struct: account
#           Decl: account_count, [], [], [], []
#             TypeDecl: account_count, [], None
#               IdentifierType: ['int']
#         TypeDecl: deposit, [], None
#           IdentifierType: ['void']
#     Compound:
#       Decl: account_number, [], [], [], []
#         TypeDecl: account_number, [], None
#           IdentifierType: ['int']
#       Decl: amount, [], [], [], []
#         TypeDecl: amount, [], None
#           IdentifierType: ['float']
#       FuncCall:
#         ID: printf
#         ExprList:
#           Constant: string, "Enter account number: "
#       FuncCall:
#         ID: scanf
#         ExprList:
#           Constant: string, "%d"
#           UnaryOp: &
#             ID: account_number
#       Decl: account_index, [], [], [], []
#         TypeDecl: account_index, [], None
#           IdentifierType: ['int']
#         UnaryOp: -
#           Constant: int, 1
#       For:
#         DeclList:
#           Decl: i, [], [], [], []
#             TypeDecl: i, [], None
#               IdentifierType: ['int']
#             Constant: int, 0
#         BinaryOp: <
#           ID: i
#           ID: account_count
#         UnaryOp: p++
#           ID: i
#         Compound:
#           If:
#             BinaryOp: ==
#               StructRef: .
#                 ArrayRef:
#                   ID: accounts
#                   ID: i
#                 ID: account_number
#               ID: account_number
#             Compound:
#               Assignment: =
#                 ID: account_index
#                 ID: i
#               Break:
#       If:
#         BinaryOp: ==
#           ID: account_index
#           UnaryOp: -
#             Constant: int, 1
#         Compound:
#           FuncCall:
#             ID: printf
#             ExprList:
#               Constant: string, "Account not found!\n"
#         Compound:
#           FuncCall:
#             ID: printf
#             ExprList:
#               Constant: string, "Enter amount to deposit: "
#           FuncCall:
#             ID: scanf
#             ExprList:
#               Constant: string, "%f"
#               UnaryOp: &
#                 ID: amount
#           Assignment: +=
#             StructRef: .
#               ArrayRef:
#                 ID: accounts
#                 ID: account_index
#               ID: balance
#             ID: amount
#           FuncCall:
#             ID: printf
#             ExprList:
#               Constant: string, "Deposit successful! Updated balance: %.2f\n"
#               StructRef: .
#                 ArrayRef:
#                   ID: accounts
#                   ID: account_index
#                 ID: balance
#   FuncDef:
#     Decl: withdraw, [], [], [], []
#       FuncDecl:
#         ParamList:
#           Decl: accounts, [], [], [], []
#             PtrDecl: []
#               TypeDecl: accounts, [], None
#                 Struct: account
#           Decl: account_count, [], [], [], []
#             TypeDecl: account_count, [], None
#               IdentifierType: ['int']
#         TypeDecl: withdraw, [], None
#           IdentifierType: ['void']
#     Compound:
#       Decl: account_number, [], [], [], []
#         TypeDecl: account_number, [], None
#           IdentifierType: ['int']
#       Decl: amount, [], [], [], []
#         TypeDecl: amount, [], None
#           IdentifierType: ['float']
#       FuncCall:
#         ID: printf
#         ExprList:
#           Constant: string, "Enter account number: "
#       FuncCall:
#         ID: scanf
#         ExprList:
#           Constant: string, "%d"
#           UnaryOp: &
#             ID: account_number
#       Decl: account_index, [], [], [], []
#         TypeDecl: account_index, [], None
#           IdentifierType: ['int']
#         UnaryOp: -
#           Constant: int, 1
#       For:
#         DeclList:
#           Decl: i, [], [], [], []
#             TypeDecl: i, [], None
#               IdentifierType: ['int']
#             Constant: int, 0
#         BinaryOp: <
#           ID: i
#           ID: account_count
#         UnaryOp: p++
#           ID: i
#         Compound:
#           If:
#             BinaryOp: ==
#               StructRef: .
#                 ArrayRef:
#                   ID: accounts
#                   ID: i
#                 ID: account_number
#               ID: account_number
#             Compound:
#               Assignment: =
#                 ID: account_index
#                 ID: i
#               Break:
#       If:
#         BinaryOp: ==
#           ID: account_index
#           UnaryOp: -
#             Constant: int, 1
#         Compound:
#           FuncCall:
#             ID: printf
#             ExprList:
#               Constant: string, "Account not found!\n"
#         Compound:
#           FuncCall:
#             ID: printf
#             ExprList:
#               Constant: string, "Enter amount to withdraw: "
#           FuncCall:
#             ID: scanf
#             ExprList:
#               Constant: string, "%f"
#               UnaryOp: &
#                 ID: amount
#           If:
#             BinaryOp: >
#               ID: amount
#               StructRef: .
#                 ArrayRef:
#                   ID: accounts
#                   ID: account_index
#                 ID: balance
#             Compound:
#               FuncCall:
#                 ID: printf
#                 ExprList:
#                   Constant: string, "Insufficient balance!\n"
#             Compound:
#               Assignment: -=
#                 StructRef: .
#                   ArrayRef:
#                     ID: accounts
#                     ID: account_index
#                   ID: balance
#                 ID: amount
#               FuncCall:
#                 ID: printf
#                 ExprList:
#                   Constant: string, "Withdrawal successful! Updated balance: %.2f\n"
#                   StructRef: .
#                     ArrayRef:
#                       ID: accounts
#                       ID: account_index
#                     ID: balance
#   FuncDef:
#     Decl: main, [], [], [], []
#       FuncDecl:
#         TypeDecl: main, [], None
#           IdentifierType: ['int']
#     Compound:
#       Decl: accounts, [], [], [], []
#         ArrayDecl: []
#           TypeDecl: accounts, [], None
#             Struct: account
#           Constant: int, 100
#       Decl: account_count, [], [], [], []
#         TypeDecl: account_count, [], None
#           IdentifierType: ['int']
#         Constant: int, 0
#       Decl: choice, [], [], [], []
#         TypeDecl: choice, [], None
#           IdentifierType: ['int']
#       While:
#         Constant: int, 1
#         Compound:
#           FuncCall:
#             ID: printf
#             ExprList:
#               Constant: string, "\n*******************\n"
#           FuncCall:
#             ID: printf
#             ExprList:
#               Constant: string, "1. Add account\n"
#           FuncCall:
#             ID: printf
#             ExprList:
#               Constant: string, "2. Display all accounts\n"
#           FuncCall:
#             ID: printf
#             ExprList:
#               Constant: string, "3. Deposit money\n"
#           FuncCall:
#             ID: printf
#             ExprList:
#               Constant: string, "4. Withdraw money\n"
#           FuncCall:
#             ID: printf
#             ExprList:
#               Constant: string, "5. Exit\n"
#           FuncCall:
#             ID: printf
#             ExprList:
#               Constant: string, "Enter your choice: "
#           FuncCall:
#             ID: scanf
#             ExprList:
#               Constant: string, "%d"
#               UnaryOp: &
#                 ID: choice
#           Switch:
#             ID: choice
#             Compound:
#               Case:
#                 Constant: int, 1
#                 FuncCall:
#                   ID: add_account
#                   ExprList:
#                     ID: accounts
#                     UnaryOp: &
#                       ID: account_count
#                 Break:
#               Case:
#                 Constant: int, 2
#                 FuncCall:
#                   ID: display_accounts
#                   ExprList:
#                     ID: accounts
#                     ID: account_count
#                 Break:
#               Case:
#                 Constant: int, 3
#                 FuncCall:
#                   ID: deposit
#                   ExprList:
#                     ID: accounts
#                     ID: account_count
#                 Break:
#               Case:
#                 Constant: int, 4
#                 FuncCall:
#                   ID: withdraw
#                   ExprList:
#                     ID: accounts
#                     ID: account_count
#                 Break:
#               Case:
#                 Constant: int, 5
#                 FuncCall:
#                   ID: printf
#                   ExprList:
#                     Constant: string, "Exiting program...\n"
#                 FuncCall:
#                   ID: exit
#                   ExprList:
#                     Constant: int, 0
#               Default:
#                 FuncCall:
#                   ID: printf
#                   ExprList:
#                     Constant: string, "Invalid choice. Please try again.\n"
# Linearized AST: FileAST Decl Struct Decl ArrayDecl TypeDecl IdentifierType Constant Decl TypeDecl IdentifierType Decl TypeDecl IdentifierType FuncDef Decl FuncDecl ParamList Decl PtrDecl TypeDecl Struct Decl PtrDecl TypeDecl IdentifierType TypeDecl IdentifierType Compound Decl ArrayDecl TypeDecl IdentifierType Constant Decl TypeDecl IdentifierType FuncCall ID ExprList Constant FuncCall ID ExprList Constant ID FuncCall ID ExprList Constant FuncCall ID ExprList Constant UnaryOp ID Assignment StructRef ArrayRef ID UnaryOp ID ID BinaryOp UnaryOp ID Constant FuncCall ID ExprList StructRef ArrayRef ID UnaryOp ID ID ID Assignment StructRef ArrayRef ID UnaryOp ID ID ID FuncCall ID ExprList Constant UnaryOp UnaryOp ID FuncDef Decl FuncDecl ParamList Decl PtrDecl TypeDecl Struct Decl TypeDecl IdentifierType TypeDecl IdentifierType Compound FuncCall ID ExprList Constant For DeclList Decl TypeDecl IdentifierType Constant BinaryOp ID ID UnaryOp ID Compound FuncCall ID ExprList Constant StructRef ArrayRef ID ID ID StructRef ArrayRef ID ID ID StructRef ArrayRef ID ID ID FuncDef Decl FuncDecl ParamList Decl PtrDecl TypeDecl Struct Decl TypeDecl IdentifierType TypeDecl IdentifierType Compound Decl TypeDecl IdentifierType Decl TypeDecl IdentifierType FuncCall ID ExprList Constant FuncCall ID ExprList Constant UnaryOp ID Decl TypeDecl IdentifierType UnaryOp Constant For DeclList Decl TypeDecl IdentifierType Constant BinaryOp ID ID UnaryOp ID Compound If BinaryOp StructRef ArrayRef ID ID ID ID Compound Assignment ID ID Break If BinaryOp ID UnaryOp Constant Compound FuncCall ID ExprList Constant Compound FuncCall ID ExprList Constant FuncCall ID ExprList Constant UnaryOp ID Assignment StructRef ArrayRef ID ID ID ID FuncCall ID ExprList Constant StructRef ArrayRef ID ID ID FuncDef Decl FuncDecl ParamList Decl PtrDecl TypeDecl Struct Decl TypeDecl IdentifierType TypeDecl IdentifierType Compound Decl TypeDecl IdentifierType Decl TypeDecl IdentifierType FuncCall ID ExprList Constant FuncCall ID ExprList Constant UnaryOp ID Decl TypeDecl IdentifierType UnaryOp Constant For DeclList Decl TypeDecl IdentifierType Constant BinaryOp ID ID UnaryOp ID Compound If BinaryOp StructRef ArrayRef ID ID ID ID Compound Assignment ID ID Break If BinaryOp ID UnaryOp Constant Compound FuncCall ID ExprList Constant Compound FuncCall ID ExprList Constant FuncCall ID ExprList Constant UnaryOp ID If BinaryOp ID StructRef ArrayRef ID ID ID Compound FuncCall ID ExprList Constant Compound Assignment StructRef ArrayRef ID ID ID ID FuncCall ID ExprList Constant StructRef ArrayRef ID ID ID FuncDef Decl FuncDecl TypeDecl IdentifierType Compound Decl ArrayDecl TypeDecl Struct Constant Decl TypeDecl IdentifierType Constant Decl TypeDecl IdentifierType While Constant Compound FuncCall ID ExprList Constant FuncCall ID ExprList Constant FuncCall ID ExprList Constant FuncCall ID ExprList Constant FuncCall ID ExprList Constant FuncCall ID ExprList Constant FuncCall ID ExprList Constant FuncCall ID ExprList Constant UnaryOp ID Switch ID Compound Case Constant FuncCall ID ExprList ID UnaryOp ID Break Case Constant FuncCall ID ExprList ID ID Break Case Constant FuncCall ID ExprList ID ID Break Case Constant FuncCall ID ExprList ID ID Break Case Constant FuncCall ID ExprList Constant FuncCall ID ExprList Constant Default FuncCall ID ExprList Constant
# Combined Input: #include <stdio.h>
# #include <stdlib.h>
# #include <string.h>
#
#
# struct account {
#     char name[50];
#     int account_number;
#     float balance;
# };
#
#
# void add_account(struct account *accounts, int *account_count) {
#     char name[50];
#     float balance;
#     printf("Enter name of account holder: ");
#     scanf("%s", name);
#     printf("Enter initial balance: ");
#     scanf("%f", &balance);
#     accounts[*account_count].account_number = *account_count + 1000;
#     strcpy(accounts[*account_count].name, name);
#     accounts[*account_count].balance = balance;
#     printf("New account added successfully!\n");
#     (*account_count)++;
# }
#
#
# void display_accounts(struct account *accounts, int account_count) {
#     printf("Account Number\tAccount Holder\t\tBalance\n");
#     for (int i = 0; i < account_count; i++) {
#         printf("%d\t\t%s\t\t%.2f\n", accounts[i].account_number, accounts[i].name, accounts[i].balance);
#     }
# }
#
#
# void deposit(struct account *accounts, int account_count) {
#     int account_number;
#     float amount;
#     printf("Enter account number: ");
#     scanf("%d", &account_number);
#     int account_index = -1;
#     for (int i = 0; i < account_count; i++) {
#         if (accounts[i].account_number == account_number) {
#             account_index = i;
#             break;
#         }
#     }
#     if (account_index == -1) {
#         printf("Account not found!\n");
#     } else {
#         printf("Enter amount to deposit: ");
#         scanf("%f", &amount);
#         accounts[account_index].balance += amount;
#         printf("Deposit successful! Updated balance: %.2f\n", accounts[account_index].balance);
#     }
# }
#
#
# void withdraw(struct account *accounts, int account_count) {
#     int account_number;
#     float amount;
#     printf("Enter account number: ");
#     scanf("%d", &account_number);
#     int account_index = -1;
#     for (int i = 0; i < account_count; i++) {
#         if (accounts[i].account_number == account_number) {
#             account_index = i;
#             break;
#         }
#     }
#     if (account_index == -1) {
#         printf("Account not found!\n");
#     } else {
#         printf("Enter amount to withdraw: ");
#         scanf("%f", &amount);
#         if (amount > accounts[account_index].balance) {
#             printf("Insufficient balance!\n");
#         } else {
#             accounts[account_index].balance -= amount;
#             printf("Withdrawal successful! Updated balance: %.2f\n", accounts[account_index].balance);
#         }
#     }
# }
#
# int main() {
#     struct account accounts[100];
#     int account_count = 0;
#     int choice;
#     while (1) {
#         printf("\n*******************\n");
#         printf("1. Add account\n");
#         printf("2. Display all accounts\n");
#         printf("3. Deposit money\n");
#         printf("4. Withdraw money\n");
#         printf("5. Exit\n");
#         printf("Enter your choice: ");
#         scanf("%d", &choice);
#         switch (choice) {
#             case 1:
#                 add_account(accounts, &account_count);
#                 break;
#             case 2:
#                 display_accounts(accounts, account_count);
#                 break;
# ...
# Processing FormAI_96687.c ...
# Processing FormAI_96688.c ...
# Processing FormAI_96689.c ...
# Processing FormAI_9669.c ...
# Processing FormAI_96690.c ...
# Processing FormAI_96691.c ...
# Processing FormAI_96692.c ...
# Processing FormAI_96693.c ...
# Processing FormAI_96694.c ...
# Processing FormAI_96695.c ...
# Processing FormAI_96696.c ...
# Processing FormAI_96697.c ...
# Processing FormAI_96698.c ...
# Processing FormAI_96699.c ...
# Processing FormAI_967.c ...
# Processing FormAI_9670.c ...
# Processing FormAI_96700.c ...
# Processing FormAI_96701.c ...
# Processing FormAI_96702.c ...
# Processing FormAI_96703.c ...
# Processing FormAI_96704.c ...
# Processing FormAI_96705.c ...
# Processing FormAI_96706.c ...
# Processing FormAI_96707.c ...
# Processing FormAI_96708.c ...
# Processing FormAI_96709.c ...
# Processing FormAI_9671.c ...
# Processing FormAI_96710.c ...
# Processing FormAI_96711.c ...
# Processing FormAI_96712.c ...
# Processing FormAI_96713.c ...
# Processing FormAI_96714.c ...
# Processing FormAI_96715.c ...
# Processing FormAI_96716.c ...
# Processing FormAI_96717.c ...
# Processing FormAI_96718.c ...
# Processing FormAI_96719.c ...
# Processing FormAI_9672.c ...
# Processing FormAI_96720.c ...
# Processing FormAI_96721.c ...
# Processing FormAI_96722.c ...
# Processing FormAI_96723.c ...
# Processing FormAI_96724.c ...
# Processing FormAI_96725.c ...
# Processing FormAI_96726.c ...
# Processing FormAI_96727.c ...
# Processing FormAI_96728.c ...
# Processing FormAI_96729.c ...
# Processing FormAI_9673.c ...
# Processing FormAI_96730.c ...
# Processing FormAI_96731.c ...
# Processing FormAI_96732.c ...
# Processing FormAI_96733.c ...
# Processing FormAI_96734.c ...
# Processing FormAI_96735.c ...
# Processing FormAI_96736.c ...
# Processing FormAI_96737.c ...
# Processing FormAI_96738.c ...
# Processing FormAI_96739.c ...
# Processing FormAI_9674.c ...
# Processing FormAI_96740.c ...
# Processing FormAI_96741.c ...
# Processing FormAI_96742.c ...
# Processing FormAI_96743.c ...
# Processing FormAI_96744.c ...
# Processing FormAI_96745.c ...
# Processing FormAI_96746.c ...
# Processing FormAI_96747.c ...
# Processing FormAI_96748.c ...
# Processing FormAI_96749.c ...
# Processing FormAI_9675.c ...
# Processing FormAI_96750.c ...
# Processing FormAI_96751.c ...
# Processing FormAI_96752.c ...
# Processing FormAI_96753.c ...
# Processing FormAI_96754.c ...
# Processing FormAI_96755.c ...
# Processing FormAI_96756.c ...
# Processing FormAI_96757.c ...
# Processing FormAI_96758.c ...
# Processing FormAI_96759.c ...
# Processing FormAI_9676.c ...
# Processing FormAI_96760.c ...
# Processing FormAI_96761.c ...
# Processing FormAI_96762.c ...
# Processing FormAI_96763.c ...
# Processing FormAI_96764.c ...
# Processing FormAI_96765.c ...
# Processing FormAI_96766.c ...
# Processing FormAI_96767.c ...
# Processing FormAI_96768.c ...
# Processing FormAI_96769.c ...
# Processing FormAI_9677.c ...
# Processing FormAI_96770.c ...
# Processing FormAI_96771.c ...
# Processing FormAI_96772.c ...
# Processing FormAI_96773.c ...
# Processing FormAI_96774.c ...
# Processing FormAI_96775.c ...
# Processing FormAI_96776.c ...
# Processing FormAI_96777.c ...
# Processing FormAI_96778.c ...
# Processing FormAI_96779.c ...
# Processing FormAI_9678.c ...
# Processing FormAI_96780.c ...
# Processing FormAI_96781.c ...
# Processing FormAI_96782.c ...
# Processing FormAI_96783.c ...
# Processing FormAI_96784.c ...
# Processing FormAI_96785.c ...
# Processing FormAI_96786.c ...
# Processing FormAI_96787.c ...
# Processing FormAI_96788.c ...
# Processing FormAI_96789.c ...
# Processing FormAI_9679.c ...
# Processing FormAI_96790.c ...
# Processing FormAI_96791.c ...
# Processing FormAI_96792.c ...
# Processing FormAI_96793.c ...
# Processing FormAI_96794.c ...
# Processing FormAI_96795.c ...
# Processing FormAI_96796.c ...
# Processing FormAI_96797.c ...
# Processing FormAI_96798.c ...
# Processing FormAI_96799.c ...
# Processing FormAI_968.c ...
# Processing FormAI_9680.c ...
# Processing FormAI_96800.c ...
# Processing FormAI_96801.c ...
# Processing FormAI_96802.c ...
# Processing FormAI_96803.c ...
# Processing FormAI_96804.c ...
# Processing FormAI_96805.c ...
# Processing FormAI_96806.c ...
# Processing FormAI_96807.c ...
# Processing FormAI_96808.c ...
# Processing FormAI_96809.c ...
# Processing FormAI_9681.c ...
# Processing FormAI_96810.c ...
# Processing FormAI_96811.c ...
# Processing FormAI_96812.c ...
# Processing FormAI_96813.c ...
# Processing FormAI_96814.c ...
# Processing FormAI_96815.c ...
# Processing FormAI_96816.c ...
# Processing FormAI_96817.c ...
# Processing FormAI_96818.c ...
# Processing FormAI_96819.c ...
# Processing FormAI_9682.c ...
# Processing FormAI_96820.c ...
# Processing FormAI_96821.c ...
# Processing FormAI_96822.c ...
# Processing FormAI_96823.c ...
# Processing FormAI_96824.c ...
# Processing FormAI_96825.c ...
# Processing FormAI_96826.c ...
# Processing FormAI_96827.c ...
# Processing FormAI_96828.c ...
# Processing FormAI_96829.c ...
# Processing FormAI_9683.c ...
# Processing FormAI_96830.c ...
# Processing FormAI_96831.c ...
# Processing FormAI_96832.c ...
# Processing FormAI_96833.c ...
# Processing FormAI_96834.c ...
# Processing FormAI_96835.c ...
# Processing FormAI_96836.c ...
# Processing FormAI_96837.c ...
# Processing FormAI_96838.c ...
# Processing FormAI_96839.c ...
# Processing FormAI_9684.c ...
# Processing FormAI_96840.c ...
# Processing FormAI_96841.c ...
# Processing FormAI_96842.c ...
# Processing FormAI_96843.c ...
# Processing FormAI_96844.c ...
# Processing FormAI_96845.c ...
# Processing FormAI_96846.c ...
# Processing FormAI_96847.c ...
# Processing FormAI_96848.c ...
# Processing FormAI_96849.c ...
# Processing FormAI_9685.c ...
# Processing FormAI_96850.c ...
# Processing FormAI_96851.c ...
# Processing FormAI_96852.c ...
# Processing FormAI_96853.c ...
# Processing FormAI_96854.c ...
# Processing FormAI_96855.c ...
# Processing FormAI_96856.c ...
# Processing FormAI_96857.c ...
# Processing FormAI_96858.c ...
# Processing FormAI_96859.c ...
# Processing FormAI_9686.c ...
# Processing FormAI_96860.c ...
# Processing FormAI_96861.c ...
# Processing FormAI_96862.c ...
# Processing FormAI_96863.c ...
# Processing FormAI_96864.c ...
# Processing FormAI_96865.c ...
# Processing FormAI_96866.c ...
# Processing FormAI_96867.c ...
# Processing FormAI_96868.c ...
# Processing FormAI_96869.c ...
# Processing FormAI_9687.c ...
# Processing FormAI_96870.c ...
# Processing FormAI_96871.c ...
# Processing FormAI_96872.c ...
# Processing FormAI_96873.c ...
# Processing FormAI_96874.c ...
# Processing FormAI_96875.c ...
# Processing FormAI_96876.c ...
# Processing FormAI_96877.c ...
# Processing FormAI_96878.c ...
# Processing FormAI_96879.c ...
# Processing FormAI_9688.c ...
# Processing FormAI_96880.c ...
# Processing FormAI_96881.c ...
# Processing FormAI_96882.c ...
# Processing FormAI_96883.c ...
# Processing FormAI_96884.c ...
# Processing FormAI_96885.c ...
# Processing FormAI_96886.c ...
# Processing FormAI_96887.c ...
# Processing FormAI_96888.c ...
# Processing FormAI_96889.c ...
# Processing FormAI_9689.c ...
# Processing FormAI_96890.c ...
# Processing FormAI_96891.c ...
# Processing FormAI_96892.c ...
# Processing FormAI_96893.c ...
# Processing FormAI_96894.c ...
# Processing FormAI_96895.c ...
# Processing FormAI_96896.c ...
# Processing FormAI_96897.c ...
# Processing FormAI_96898.c ...
# Processing FormAI_96899.c ...
# Processing FormAI_969.c ...
# Processing FormAI_9690.c ...
# Processing FormAI_96900.c ...
# Processing FormAI_96901.c ...
# Processing FormAI_96902.c ...
# Processing FormAI_96903.c ...
# Processing FormAI_96904.c ...
# Processing FormAI_96905.c ...
# Processing FormAI_96906.c ...
# Processing FormAI_96907.c ...
# Processing FormAI_96908.c ...
# Processing FormAI_96909.c ...
# Processing FormAI_9691.c ...
# Processing FormAI_96910.c ...
# Processing FormAI_96911.c ...
# Processing FormAI_96912.c ...
# Processing FormAI_96913.c ...
# Processing FormAI_96914.c ...
# Processing FormAI_96915.c ...
# Processing FormAI_96916.c ...
# Processing FormAI_96917.c ...
# Processing FormAI_96918.c ...
# Processing FormAI_96919.c ...
# Processing FormAI_9692.c ...
# Processing FormAI_96920.c ...
# Processing FormAI_96921.c ...
# Processing FormAI_96922.c ...
# Processing FormAI_96923.c ...
# Processing FormAI_96924.c ...
# Processing FormAI_96925.c ...
# Processing FormAI_96926.c ...
# Processing FormAI_96927.c ...
# Processing FormAI_96928.c ...
# Processing FormAI_96929.c ...
# Processing FormAI_9693.c ...
# Processing FormAI_96930.c ...
# Processing FormAI_96931.c ...
# Processing FormAI_96932.c ...
# Processing FormAI_96933.c ...
# Processing FormAI_96934.c ...
# Processing FormAI_96935.c ...
# Processing FormAI_96936.c ...
# Processing FormAI_96937.c ...
# Processing FormAI_96938.c ...
# Processing FormAI_96939.c ...
# Processing FormAI_9694.c ...
# Processing FormAI_96940.c ...
# Processing FormAI_96941.c ...
# Processing FormAI_96942.c ...
# Processing FormAI_96943.c ...
# Processing FormAI_96944.c ...
# Processing FormAI_96945.c ...
# Processing FormAI_96946.c ...
# Processing FormAI_96947.c ...
# Processing FormAI_96948.c ...
# Processing FormAI_96949.c ...
# Processing FormAI_9695.c ...
# Processing FormAI_96950.c ...
# Processing FormAI_96951.c ...
# Processing FormAI_96952.c ...
# Processing FormAI_96953.c ...
# Processing FormAI_96954.c ...
# Processing FormAI_96955.c ...
# Processing FormAI_96956.c ...
# Processing FormAI_96957.c ...
# Processing FormAI_96958.c ...
# Processing FormAI_96959.c ...
# Processing FormAI_9696.c ...
# Processing FormAI_96960.c ...
# Processing FormAI_96961.c ...
# Processing FormAI_96962.c ...
# Processing FormAI_96963.c ...
# Processing FormAI_96964.c ...
# Processing FormAI_96965.c ...
# Processing FormAI_96966.c ...
# Processing FormAI_96967.c ...
# Processing FormAI_96968.c ...
# Processing FormAI_96969.c ...
# Processing FormAI_9697.c ...
# Processing FormAI_96970.c ...
# Processing FormAI_96971.c ...
# Processing FormAI_96972.c ...
# Processing FormAI_96973.c ...
# Processing FormAI_96974.c ...
# Processing FormAI_96975.c ...
# Processing FormAI_96976.c ...
# Processing FormAI_96977.c ...
# Processing FormAI_96978.c ...
# Processing FormAI_96979.c ...
# Processing FormAI_9698.c ...
# Processing FormAI_96980.c ...
# Processing FormAI_96981.c ...
# Processing FormAI_96982.c ...
# Processing FormAI_96983.c ...
# Processing FormAI_96984.c ...
# Processing FormAI_96985.c ...
# Processing FormAI_96986.c ...
# Processing FormAI_96987.c ...
# Processing FormAI_96988.c ...
# Processing FormAI_96989.c ...
# Processing FormAI_9699.c ...
# Processing FormAI_96990.c ...
# Processing FormAI_96991.c ...
# Processing FormAI_96992.c ...
# Processing FormAI_96993.c ...
# Processing FormAI_96994.c ...
# Processing FormAI_96995.c ...
# Processing FormAI_96996.c ...
# Processing FormAI_96997.c ...
# Processing FormAI_96998.c ...
# Processing FormAI_96999.c ...
# Processing FormAI_97.c ...
# Processing FormAI_970.c ...
# Processing FormAI_9700.c ...
# Processing FormAI_97000.c ...
# Processing FormAI_97001.c ...
# Processing FormAI_97002.c ...
# Processing FormAI_97003.c ...
# Processing FormAI_97004.c ...
# Processing FormAI_97005.c ...
# Processing FormAI_97006.c ...
# Processing FormAI_97007.c ...
# Processing FormAI_97008.c ...
# Processing FormAI_97009.c ...
# Processing FormAI_9701.c ...
# Processing FormAI_97010.c ...
# Processing FormAI_97011.c ...
# Processing FormAI_97012.c ...
# Processing FormAI_97013.c ...
# Processing FormAI_97014.c ...
# Processing FormAI_97015.c ...
# Processing FormAI_97016.c ...
# Processing FormAI_97017.c ...
# Processing FormAI_97018.c ...
# Processing FormAI_97019.c ...
# Processing FormAI_9702.c ...
# Processing FormAI_97020.c ...
# Processing FormAI_97021.c ...
# Processing FormAI_97022.c ...
# Processing FormAI_97023.c ...
# Processing FormAI_97024.c ...
# Processing FormAI_97025.c ...
# Processing FormAI_97026.c ...
# Processing FormAI_97027.c ...
# Processing FormAI_97028.c ...
# Processing FormAI_97029.c ...
# Processing FormAI_9703.c ...
# Processing FormAI_97030.c ...
# Processing FormAI_97031.c ...
# Processing FormAI_97032.c ...
# Processing FormAI_97033.c ...
# Processing FormAI_97034.c ...
# Processing FormAI_97035.c ...
# Processing FormAI_97036.c ...
# Processing FormAI_97037.c ...
# Processing FormAI_97038.c ...
# Processing FormAI_97039.c ...
# Processing FormAI_9704.c ...
# Processing FormAI_97040.c ...
# Processing FormAI_97041.c ...
# Processing FormAI_97042.c ...
# Processing FormAI_97043.c ...
# Processing FormAI_97044.c ...
# Processing FormAI_97045.c ...
# Processing FormAI_97046.c ...
# Processing FormAI_97047.c ...
# Processing FormAI_97048.c ...
# Processing FormAI_97049.c ...
# Processing FormAI_9705.c ...
# Processing FormAI_97050.c ...
# Processing FormAI_97051.c ...
# Processing FormAI_97052.c ...
# Processing FormAI_97053.c ...
# Processing FormAI_97054.c ...
# Processing FormAI_97055.c ...
# Processing FormAI_97056.c ...
# Processing FormAI_97057.c ...
# Processing FormAI_97058.c ...
# Processing FormAI_97059.c ...
# Processing FormAI_9706.c ...
# Processing FormAI_97060.c ...
# Processing FormAI_97061.c ...
# Processing FormAI_97062.c ...
# Processing FormAI_97063.c ...
# Processing FormAI_97064.c ...
# Processing FormAI_97065.c ...
# Processing FormAI_97066.c ...
# Processing FormAI_97067.c ...
# Processing FormAI_97068.c ...
# Processing FormAI_97069.c ...
# Processing FormAI_9707.c ...
# Processing FormAI_97070.c ...
# Processing FormAI_97071.c ...
# Processing FormAI_97072.c ...
# Processing FormAI_97073.c ...
# Processing FormAI_97074.c ...
# Processing FormAI_97075.c ...
# Processing FormAI_97076.c ...
# Processing FormAI_97077.c ...
# Processing FormAI_97078.c ...
# Processing FormAI_97079.c ...
# Processing FormAI_9708.c ...
# Processing FormAI_97080.c ...
# Processing FormAI_97081.c ...
# Processing FormAI_97082.c ...
# Processing FormAI_97083.c ...
# Processing FormAI_97084.c ...
# Processing FormAI_97085.c ...
# Processing FormAI_97086.c ...
# Processing FormAI_97087.c ...
# Processing FormAI_97088.c ...
# Processing FormAI_97089.c ...
# Processing FormAI_9709.c ...
# Processing FormAI_97090.c ...
# Processing FormAI_97091.c ...
# Processing FormAI_97092.c ...
# Processing FormAI_97093.c ...
# Processing FormAI_97094.c ...
# Processing FormAI_97095.c ...
# Processing FormAI_97096.c ...
# Processing FormAI_97097.c ...
# Processing FormAI_97098.c ...
# Processing FormAI_97099.c ...
# Processing FormAI_971.c ...
# Processing FormAI_9710.c ...
# Processing FormAI_97100.c ...
# Processing FormAI_97101.c ...
# Processing FormAI_97102.c ...
# Processing FormAI_97103.c ...
# Processing FormAI_97104.c ...
# Processing FormAI_97105.c ...
# Processing FormAI_97106.c ...
# Processing FormAI_97107.c ...
# Processing FormAI_97108.c ...
# Processing FormAI_97109.c ...
# Processing FormAI_9711.c ...
# Processing FormAI_97110.c ...
# Processing FormAI_97111.c ...
# Processing FormAI_97112.c ...
# Processing FormAI_97113.c ...
# Processing FormAI_97114.c ...
# Processing FormAI_97115.c ...
# Processing FormAI_97116.c ...
# Processing FormAI_97117.c ...
# Processing FormAI_97118.c ...
# Processing FormAI_97119.c ...
# Processing FormAI_9712.c ...
# Processing FormAI_97120.c ...
# Processing FormAI_97121.c ...
# Processing FormAI_97122.c ...
# Processing FormAI_97123.c ...
# Processing FormAI_97124.c ...
# Processing FormAI_97125.c ...
# Processing FormAI_97126.c ...
# Processing FormAI_97127.c ...
# Processing FormAI_97128.c ...
# Processing FormAI_97129.c ...
# Processing FormAI_9713.c ...
# Processing FormAI_97130.c ...
# Processing FormAI_97131.c ...
# Processing FormAI_97132.c ...
# Processing FormAI_97133.c ...
# Processing FormAI_97134.c ...
# Processing FormAI_97135.c ...
# Processing FormAI_97136.c ...
# Processing FormAI_97137.c ...
# Processing FormAI_97138.c ...
# Processing FormAI_97139.c ...
# Processing FormAI_9714.c ...
# Processing FormAI_97140.c ...
# Processing FormAI_97141.c ...
# Processing FormAI_97142.c ...
# Processing FormAI_97143.c ...
# Processing FormAI_97144.c ...
# Processing FormAI_97145.c ...
# Processing FormAI_97146.c ...
# Processing FormAI_97147.c ...
# Processing FormAI_97148.c ...
# Processing FormAI_97149.c ...
# Processing FormAI_9715.c ...
# Processing FormAI_97150.c ...
# Processing FormAI_97151.c ...
# Processing FormAI_97152.c ...
# Processing FormAI_97153.c ...
# Processing FormAI_97154.c ...
# Processing FormAI_97155.c ...
# Processing FormAI_97156.c ...
# Processing FormAI_97157.c ...
# Processing FormAI_97158.c ...
# Processing FormAI_97159.c ...
# Processing FormAI_9716.c ...
# Processing FormAI_97160.c ...
# Processing FormAI_97161.c ...
# Processing FormAI_97162.c ...
# Processing FormAI_97163.c ...
# Processing FormAI_97164.c ...
# Processing FormAI_97165.c ...
# Processing FormAI_97166.c ...
# Processing FormAI_97167.c ...
